# %%
import json
json_path = '../raw/dados_empresaA.json'

# %%
with open(json_path, 'r') as file:
    data = file.readlines()

# %%
data
# Out:
# ['[{"Nome do Produto":"Blush em p\\u00f3","Categoria do Produto":"Eletrodom\\u00e9sticos","Pre\\u00e7o do Produto (R$)":79.41,"Quantidade em Estoque":7,"Filial":"Filial 7"},\n',
#  '{"Nome do Produto":"L\\u00e1pis de sobrancelha","Categoria do Produto":"Eletrodom\\u00e9sticos","Pre\\u00e7o do Produto (R$)":85.47,"Quantidade em Estoque":78,"Filial":"Filial 8"},\n',
#  '{"Nome do Produto":"Base l\\u00edquida","Categoria do Produto":"Roupas","Pre\\u00e7o do Produto (R$)":75.02,"Quantidade em Estoque":34,"Filial":"Filial 8"},\n',
#  '{"Nome do Produto":"Base l\\u00edquida","Categoria do Produto":"Roupas","Pre\\u00e7o do Produto (R$)":44.94,"Quantidade em Estoque":90,"Filial":"Filial 10"},\n',
#  '{"Nome do Produto":"L\\u00e1pis de sobrancelha","Categoria do Produto":"Alimentos","Pre\\u00e7o do Produto (R$)":58.63,"Quantidade em Estoque":91,"Filial":"Filial 7"},\n',
# ...

# %%
with open(json_path, "r") as file:
    json_data = json.load(file)

# %%
json_data
# Out:
# [{'Nome do Produto': 'Blush em pó',
#   'Categoria do Produto': 'Eletrodomésticos',
#   'Preço do Produto (R$)': 79.41,
#   'Quantidade em Estoque': 7,
#   'Filial': 'Filial 7'},
#  {'Nome do Produto': 'Lápis de sobrancelha',
#   'Categoria do Produto': 'Eletrodomésticos',
#   'Preço do Produto (R$)': 85.47,
#   'Quantidade em Estoque': 78,
#   'Filial': 'Filial 8'},
#  {'Nome do Produto': 'Base líquida',
#   'Categoria do Produto': 'Roupas',
#   'Preço do Produto (R$)': 75.02,
#   'Quantidade em Estoque': 34,
#   'Filial': 'Filial 8'},
#  {'Nome do Produto': 'Base líquida',
#   'Categoria do Produto': 'Roupas',
#   'Preço do Produto (R$)': 44.94,
#   'Quantidade em Estoque': 90,
#   'Filial': 'Filial 10'},
#  {'Nome do Produto': 'Lápis de sobrancelha',
#   'Categoria do Produto': 'Alimentos',
#   'Preço do Produto (R$)': 58.63,
#   'Quantidade em Estoque': 91,
#   'Filial': 'Filial 7'},
#  {'Nome do Produto': 'Blush em pó',
#   'Categoria do Produto': 'Roupas',
# ...

# %%
csv_path = "../raw/dados_empresaB.csv"
